# %% [markdown]
# # Your Guide to Agent-Factory!

# %% [markdown]
# Welcome to your entry point for using Agent-Factory!
#
# This notebook will guide you through the process of creating, running and, perhaps most importantly, evaluating your first agent. As a "[hello-world](https://en.wikipedia.org/wiki/%22Hello,_World!%22_program)" example, we will build an agent that summarizes text content from a given webpage URL. This notebook includes all execution outputs so you can follow along without having to execute it. If you prefer to start fresh and try it yourself, you can select from the Jupyter Notebook's menu: `Edit -> Clear All Outputs`.
#
# But, before we begin:
#
# ### What is Agent-Factory?
#
# Agent-Factory is a framework that enables users to build and deploy AI agents through natural language prompts, lowering the technical barrier of entry for non-AI experts.
#
# ### How does it work?
#
# The main concepts you will need to understand to get you started are:
#
# - **Task**: The high-level description of what you want to achieve with your agent. In this case, we want to summarize text content from a given webpage URL.
#
# - **Manufacturing Agent**: The agent that will help you create your own agents. Think of it as you own personal alchemist-druid! You submit your vision of your ideal minion-assistant that you need help with for a very specific task, and the Manufacturing Agent will fulfill your wish.
#
#   - _In practice:_ A server, running on the background, that receives requests as a natural language prompt, and builds the Target Agent.
#
# - **Target Agent**: The agent that the Manufacturing Agent creates for you, tailored to do the best that it can to complete your task.
# It is a fully functional agent that can be run independently, anywhere you like, and it will have its own set of very specific capabilities and requirements, tailored to the specific task you requested.
#
#   - _In practice:_ A directory containing of Python code (agent.py) that implements the Target Agent, along with all the files necessary for the agent to be successfully run (`tools`, `requirements.txt`, `agent_parameters.json`, etc.).
#
# - **Criteria Agent**: The agent that can help you generate a set of criteria, aka **Evaluation Case**, to evaluate the Target Agent. You can imagine these criteria as a check-list for the Target Agent to ensure that has completed the task you requested as intended. **NOTE:** these criteria can also be manually defined by you. A recommended flow would be that you first generate a set with the Criteria Agent, and then you review and refine them to your needs.
#
#   - _In practice:_ A structured JSON file that contains the evaluation criteria, such as the input data, expected output, and any other relevant information needed to evaluate the Target Agent.
#
# - **Agent Judge**: The agent that will execute the Target Agent against the Evaluation Case and provide a score based on how well it performed. This is the final step to ensure that the Target Agent is capable of completing the task you requested.
#
#   - _In practice:_ The Agent Judge will read through the Target Agent's output (traces) and compare it to all the criteria defined in the Evaluation Case, scoring whether the criteria were met (found in the output) or not.

# %% [markdown]
# ### Installation
#
# Before running this notebook, ensure that you have installed Agent-Factory, by following the instructions in the [Installation Guide](getting-started/installation.md). Don't forget to also create a .env file with your OpenAI and Tavily API keys, as they are necessary for this notebook.
#
# ### Setup
#
# #### Jupyter Notebook
#
# To start this notebook, in a terminal with the project's virtual environment activated, run:
# ```bash
# uv run --with jupyter jupyter lab
# ```
# and you will now be able to run the commands below from within this notebook.
#
# #### Agent-Factory Server
#
# In another terminal (not inside this notebook), move to the src/agent-factory directory and start the agent-factory server in `--nochat` mode:
#
# ```bash
# cd src/agent_factory && uv run . --host 0.0.0.0 --port 8080 --nochat
# ```
#
# This will prepare the Manufacturing Agent to receive requests and build any Target Agent you ask.
# The `--nochat` flag is used so that the Manufacturing Agent "one-shots" your request, meaning it will not engage in a back-and-forth conversation with you, but rather will try to fulfill your request in one go.

# %% [markdown]
# ### Let's build!

# %%
# Necessary to run the Target Agent within a notebook environment
import nest_asyncio

nest_asyncio.apply()

# %%
# This notebook is in under the /docs directory, so we need to go up one level to run the agent-factory command
# %cd ../
# Out:
# /home/kostis/MZAI/agent-factory

# %% [markdown]
# Let's ask the Manufacturing Agent to create the Target Agent for us by providing our prompt and an output directory.

# %%
# The --active flag for uv run enables to use the preconfigured active virtual env instead of jupyter's environment
# !uv run --active agent-factory "Summarize text content from a given webpage URL" --output_dir hello_world
# Out:
# /home/kostis/.cache/uv/archive-v0/tJFHV0c7OHrqMpkwp_PhM/lib/python3.13/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.3 is exactly one major version older than the runtime version 6.31.1 at a2a.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# [08/12/25 13:56:33] INFO     A2AClient initialized.        ]8;id=160684;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=597528;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#50\50]8;;\
#                     INFO     No request ID provided,          ]8;id=78310;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py\client_utils.py]8;;\:]8;id=659058;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py#42\42]8;;\
#                              generating a new one
#                     INFO     Request ID:                      ]8;id=758274;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py\client_utils.py]8;;\:]8;id=498676;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py#50\50]8;;\
#                              6fb0fc73-14a4-4e6b-aa5e-a24333d0
#                              95bd
# [08/12/25 13:56:49] INFO     {'id':                           ]8;id=590909;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py\client_utils.py]8;;\:]8;id=202097;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py#64\64]8;;\
#                              '6fb0fc7314a44e6baa5ea24333d095b
#                              d', 'jsonrpc': '2.0', 'result':
#                              {'contextId':
#                              '247a6d64fc2f4fd5864f0b3b63bb9da
#                              8', 'history': [{'contextId':
#                              '247a6d64fc2f4fd5864f0b3b63bb9da
#                              8', 'kind': 'message',
#                              'messageId':
#                              '9988219c50cc48558f41ced42b1073b
#                              4', 'parts': [{'kind': 'text',
#                              'text': 'Summarize text content
#                              from a given webpage URL'}],
#                              'role': 'user', 'taskId':
#                              '899eb020-c212-48da-a888-1325627
#                              b3768'}], 'id':
#                              '899eb020-c212-48da-a888-1325627
#                              b3768', 'kind': 'task',
#                              'status': {'message':
#                              {'contextId':
#                              '247a6d64fc2f4fd5864f0b3b63bb9da
#                              8', 'kind': 'message',
#                              'messageId':
#                              'b1d04ab8-3ff4-49a0-93e0-50aef25
#                              2bb9e', 'parts': [{'kind':
#                              'text', 'text': '{"message":"✅
#                              Done! Your agent is
#                              ready!","status":"completed","im
#                              ports":"from any_agent.tools
#                              import
#                              visit_webpage","agent_instructio
#                              ns":"You are an assistant that
#                              follows this concise multi–step
#                              workflow to produce a
#                              high-quality summary for any
#                              public
#                              webpage:\\n\\nSTEP-BY-STEP
#                              PLAN\\n1. Receive a webpage URL
#                              from the user.\\n2. Use the
#                              `visit_webpage` tool to download
#                              the page in Markdown.\\n3. Parse
#                              the Markdown and extract the
#                              primary textual content. Ignore
#                              navigation, ads, footers,
#                              scripts or non-informational
#                              elements. Keep focus on headings
#                              and paragraphs that convey the
#                              core message.\\n4. Produce a
#                              concise summary of the extracted
#                              content in clear English
#                              (≈100–150 words). Capture the
#                              main ideas, arguments, and
#                              conclusions without adding
#                              external information or
#                              speculation.\\n5. Return a JSON
#                              object that follows the
#                              `StructuredOutput` schema with
#                              exactly two fields: `url` (the
#                              provided URL) and `summary` (the
#                              generated concise
#                              summary).\\n\\nADDITIONAL
#                              GUIDELINES\\n• If the page
#                              cannot be fetched or has little
#                              textual content, explain the
#                              issue briefly in the `summary`
#                              field.\\n• Do not output
#                              anything except the valid JSON
#                              that matches the schema.\\n•
#                              Stay within 1000 total tokens
#                              for any intermediate
#                              reasoning.","tools":"TOOLS =
#                              [\\n
#                              visit_webpage,\\n]","structured_
#                              outputs":"class
#                              StructuredOutput(BaseModel):\\n
#                              url: str = Field(...,
#                              description=\\"The original
#                              webpage URL provided by the
#                              user.\\")\\n    summary: str =
#                              Field(..., description=\\"A
#                              concise English summary
#                              (≈100–150 words) of the main
#                              page
#                              content.\\")","cli_args":"url:
#                              str","agent_description":"Given
#                              a webpage URL, the agent fetches
#                              the page, extracts its main
#                              text, and returns a concise
#                              summary.","prompt_template":"f\\
#                              "Summarize the main text content
#                              from this webpage:
#                              {url}\\"","readme":"## Setup
#                              Instructions\\n\\n1. **Clone the
#                              repository** (or download
#                              `agent.py`).\\n2. **Create a
#                              Python virtual environment**
#                              (optional but recommended).\\n3.
#                              **Install the `uv` package
#                              manager**  \\n   • macOS &
#                              Linux: `curl -LsSf
#                              https://astral.sh/uv/install.sh
#                              | sh`  \\n   • Windows
#                              (PowerShell): `powershell
#                              -ExecutionPolicy ByPass -c
#                              \\"irm
#                              https://astral.sh/uv/install.ps1
#                              | iex\\"`\\n4. **Create a `.env`
#                              file** in the project root and
#                              add your OpenAI API key
#                              (required by any-agent):\\n\\n
#                              ```env\\n
#                              OPENAI_API_KEY=your_openai_key_h
#                              ere\\n   ```\\n\\n   No other
#                              environment variables are
#                              necessary for this agent.\\n5.
#                              **Install dependencies & run the
#                              agent**:\\n\\n   ```bash\\n   uv
#                              run --with-requirements
#                              requirements.txt --python 3.13
#                              python agent.py --url
#                              \\"https://example.com\\"\\n
#                              ```\\n\\nThe agent will output
#                              the JSON summary and write the
#                              full execution trace to
#                              `agent_eval_trace.json`.","depen
#                              dencies":"any-agent==0.25.0\\npy
#                              thon-dotenv\\nfire"}'}], 'role':
#                              'agent', 'taskId':
#                              '899eb020-c212-48da-a888-1325627
#                              b3768'}, 'state': 'completed',
#                              'timestamp':
#                              '2025-08-12T10:56:49.849490+00:0
#                              0'}}}
#                     INFO     Received response from agent:    ]8;id=483324;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py\client_utils.py]8;;\:]8;id=667977;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/client_utils.py#66\66]8;;\
#                              {'message': '✅ Done! Your agent
#                              is ready!', 'status':
#                              'completed', 'imports': 'from
#                              any_agent.tools import
#                              visit_webpage',
#                              'agent_instructions': 'You are
#                              an assistant that follows this
#                              concise multi–step workflow to
#                              produce a high-quality summary
#                              for any public
#                              webpage:\n\nSTEP-BY-STEP
#                              PLAN\n1. Receive a webpage URL
#                              from the user.\n2. Use the
#                              `visit_webpage` tool to download
#                              the page in Markdown.\n3. Parse
#                              the Markdown and extract the
#                              primary textual content. Ignore
#                              navigation, ads, footers,
#                              scripts or non-informational
#                              elements. Keep focus on headings
#                              and paragraphs that convey the
#                              core message.\n4. Produce a
#                              concise summary of the extracted
#                              content in clear English
#                              (≈100–150 words). Capture the
#                              main ideas, arguments, and
#                              conclusions without adding
#                              external information or
#                              speculation.\n5. Return a JSON
#                              object that follows the
#                              `StructuredOutput` schema with
#                              exactly two fields: `url` (the
#                              provided URL) and `summary` (the
#                              generated concise
#                              summary).\n\nADDITIONAL
#                              GUIDELINES\n• If the page cannot
#                              be fetched or has little textual
#                              content, explain the issue
#                              briefly in the `summary`
#                              field.\n• Do not output anything
#                              except the valid JSON that
#                              matches the schema.\n• Stay
#                              within 1000 total tokens for any
#                              intermediate reasoning.',
#                              'tools': 'TOOLS = [\n
#                              visit_webpage,\n]',
#                              'structured_outputs': 'class
#                              StructuredOutput(BaseModel):\n
#                              url: str = Field(...,
#                              description="The original
#                              webpage URL provided by the
#                              user.")\n    summary: str =
#                              Field(..., description="A
#                              concise English summary
#                              (≈100–150 words) of the main
#                              page content.")', 'cli_args':
#                              'url: str', 'agent_description':
#                              'Given a webpage URL, the agent
#                              fetches the page, extracts its
#                              main text, and returns a concise
#                              summary.', 'prompt_template':
#                              'f"Summarize the main text
#                              content from this webpage:
#                              {url}"', 'readme': '## Setup
#                              Instructions\n\n1. **Clone the
#                              repository** (or download
#                              `agent.py`).\n2. **Create a
#                              Python virtual environment**
#                              (optional but recommended).\n3.
#                              **Install the `uv` package
#                              manager**  \n   • macOS & Linux:
#                              `curl -LsSf
#                              https://astral.sh/uv/install.sh
#                              | sh`  \n   • Windows
#                              (PowerShell): `powershell
#                              -ExecutionPolicy ByPass -c "irm
#                              https://astral.sh/uv/install.ps1
#                              | iex"`\n4. **Create a `.env`
#                              file** in the project root and
#                              add your OpenAI API key
#                              (required by any-agent):\n\n
#                              ```env\n
#                              OPENAI_API_KEY=your_openai_key_h
#                              ere\n   ```\n\n   No other
#                              environment variables are
#                              necessary for this agent.\n5.
#                              **Install dependencies & run the
#                              agent**:\n\n   ```bash\n   uv
#                              run --with-requirements
#                              requirements.txt --python 3.13
#                              python agent.py --url
#                              "https://example.com"\n
#                              ```\n\nThe agent will output the
#                              JSON summary and write the full
#                              execution trace to
#                              `agent_eval_trace.json`.',
#                              'dependencies':
#                              'any-agent==0.25.0\npython-doten
#                              v\nfire'}
#                     INFO     Saving agent artifacts to     ]8;id=612343;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py\agent_generator.py]8;;\:]8;id=680631;file:///home/kostis/MZAI/agent-factory/src/agent_factory/agent_generator.py#62\62]8;;\
#                              hello_world folder on Local
#                              Storage
#                     INFO     Agent files saved to folder           ]8;id=88967;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/storage.py\storage.py]8;;\:]8;id=837038;file:///home/kostis/MZAI/agent-factory/src/agent_factory/utils/storage.py#37\37]8;;\
#                              generated_workflows/hello_world

# %% [markdown]
# Now that the Target Agent has been created, let's navigate to the directory where it was created and see the files it generated.

# %%
# %cd generated_workflows/hello_world
# %ls
# Out:
# /home/kostis/MZAI/agent-factory/generated_workflows/hello_world
# agent_parameters.json  agent.py  README.md  requirements.txt  tools/

# %% [markdown]
# Next step: let's run it!
#
# We are using `uv` to explicitly define the Python version we want to use, in this case, Python 3.13, which packages to install from the generated requirements.txt file, and,
# finally, the input for the Target Agent, i.e. the URL we want to summarize.

# %%
# !uv run --with-requirements requirements.txt --python 3.13 python agent.py --url https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-any-llm-provider/
# Out:
# warning: `VIRTUAL_ENV=/home/kostis/.cache/uv/archive-v0/tJFHV0c7OHrqMpkwp_PhM` does not match the project environment path `/home/kostis/MZAI/agent-factory/.venv` and will be ignored; use `--active` to target the active environment instead
# /home/kostis/MZAI/agent-factory/.venv/lib/python3.13/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.3 is exactly one major version older than the runtime version 6.31.1 at a2a.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ╭──────────────────────────────── CALL_LLM: o3 ────────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "\nYou are an assistant that follows this concise multi–s │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "content": "Summarize the main text content from this webpage: https │ │
# │ │     "role": "user"                                                       │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "visit_webpage",                                        │ │
# │ │     "tool.args": "{\"url\":\"https://blog.mozilla.ai/introducing-any-llm │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 444,                                                   │ │
# │ │   "output_tokens": 51,                                                   │ │
# │ │   "input_cost": 0.000888,                                                │ │
# │ │   "output_cost": 0.000408                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────── EXECUTE_TOOL: visit_webpage ─────────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ "{\"url\":\"https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ 🌆 ]8;id=409651;https://blog.mozilla.ai\Mozilla.ai]8;;\ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ │ │
# │ │ ┃ Introducing any-llm: A unified API to access any LLM provider  ]8;id=850545;#/portal/signin\Sign]8;;\  ┃ │ │
# │ │ ┃  ]8;id=666603;#/portal/signin\in]8;;\ ]8;id=953633;#/portal/signup\Subscribe]8;;\ Introducing any-llm: A unified API to access any LLM   ┃ │ │
# │ │ ┃                               provider                               ┃ │ │
# │ │ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=498513;/author/nathan/\Nathan Brake]8;;\ When it comes to using LLMs, it’s not always a question  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers.                                                               │ │
# │ │                                                                          │ │
# │ │                               ]8;id=333680;/author/nathan/\Nathan Brake]8;;\                               │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=391832;/content/images/size/w1200/2025/07/any-llm.jpeg\Introducing any-llm: A unified API to access any LLM provider]8;;\ Jul 22, │ │
# │ │ ]8;id=437183;https://pdimagearchive.org/images/bfb9c099-b4f3-41b2-8b4a-99773d86d7ba/\Tail”, a Zulu fairy tale]8;;\ When it comes to using Large Language Models    │ │
# │ │ (LLMs), it’s not always a question of which model to use: it’s also a    │ │
# │ │ matter of choosing who provides the LLM and where it is deployed. As     │ │
# │ │ ]8;id=159943;https://blog.mozilla.ai/running-an-open-source-llm-in-2025/\we’ve written about previously]8;;\, there are many options available for how │ │
# │ │ to access an LLM. The provider you choose to use can have implications   │ │
# │ │ in terms of cost, latency, and security. Most AI labs offer their own    │ │
# │ │ provider platform (OpenAI, Google, Mistral, etc.), and other provider    │ │
# │ │ platforms (Azure, AWS, Cerebras, etc.) provide access to a wide variety  │ │
# │ │ of LLMs. But what if you want to build your LLM application without      │ │
# │ │ having to worry about being locked in to a certain provider? Today,      │ │
# │ │ we’re happy to announce the release of our new Python library: ]8;id=573997;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\any-llm]8;;\!  │ │
# │ │ any-llm provides a simple unified interface to access the most popular   │ │
# │ │ providers. By changing only a ]8;id=751562;https://mozilla-ai.github.io/any-llm/quickstart/?ref=blog.mozilla.ai#basic-usage\single configuration parameter]8;;\, you can    │ │
# │ │ easily switch between providers and models.                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │  from any_llm import completion                                          │ │
# │ │  import os                                                               │ │
# │ │  # Make sure you have the appropriate environment variable set           │ │
# │ │  assert os.environ.get('MISTRAL_API_KEY')                                │ │
# │ │  # Basic completion                                                      │ │
# │ │  response = completion(                                                  │ │
# │ │      model="mistral/mistral-small-latest", # <provider_id>/<model_id>    │ │
# │ │      messages=[{"role": "user", "content": "Hello!"}]                    │ │
# │ │  )                                                                       │ │
# │ │  print(response.choices[0].message.content)                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ any-llm fills a gap in the LLM provider interface landscape through      │ │
# │ │ several key design principles:                                           │ │
# │ │                                                                          │ │
# │ │  1 Use of provider SDKs: any-llm leverages official provider SDKs when   │ │
# │ │    available, reducing the maintenance burden and ensuring               │ │
# │ │    compatibility.                                                        │ │
# │ │  2 Committed to active maintenance: any-llm is integrated with           │ │
# │ │    ]8;id=798703;https://github.com/mozilla-ai/any-agent?ref=blog.mozilla.ai\any-agent]8;;\, one of our most community-engaged projects, so we're       │ │
# │ │    motivated to maintain it.                                             │ │
# │ │  3 No proxy or gateway server required: no need to set up another        │ │
# │ │    service as a gateway: download the any-llm SDK, and you’re good to    │ │
# │ │    communicate with all the supported providers, without having to send  │ │
# │ │    your data through another third-party provider. You can view the list │ │
# │ │    of our supported providers ]8;id=867307;https://mozilla-ai.github.io/any-llm/providers/?ref=blog.mozilla.ai\here]8;;\. OpenAI API Standard                  │ │
# │ │                                                                          │ │
# │ │ ──────────────────────────────────────────────────────────────────────── │ │
# │ │                                                                          │ │
# │ │   The ]8;id=478610;https://openai.com/index/openai-api/?ref=blog.mozilla.ai\OpenAI API]8;;\ has become the standard for LLM provider interfaces.    │ │
# │ │  Although some providers provide perfect compatibility with the OpenAI   │ │
# │ │    API standard, others (like Mistral, Anthropic, etc.) may slightly     │ │
# │ │     diverge from the OpenAI standard when it comes to expected input     │ │
# │ │ parameters and output values. In order to make it easy to switch between │ │
# │ │  these providers, this creates a need for lightweight wrappers that can  │ │
# │ │  gracefully handle these differences while maintaining as consistent an  │ │
# │ │    interface as possible. any-llm solves this problem by normalizing     │ │
# │ │   outputs to return OpenAI ChatCompletion objects, regardless of which   │ │
# │ │   provider is used under the hood. The objects are returned as OpenAI    │ │
# │ │  Pydantic models, so you can access them just as you would if you were   │ │
# │ │     using the official OpenAI API SDK. You can view the any-llm API      │ │
# │ │   documentation ]8;id=894231;https://mozilla-ai.github.io/any-llm/api/completion/?ref=blog.mozilla.ai\here]8;;\. And to see how it relates to existing solutions,   │ │
# │ │               read on. Shortcomings of Existing Solutions                │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ Several excellent open-source Python libraries already exist to address  │ │
# │ │ the challenge of interacting with various LLM providers, but each comes  │ │
# │ │    with its own set of limitations. One popular solution, ]8;id=399629;https://github.com/BerriAI/litellm?ref=blog.mozilla.ai\LiteLLM]8;;\, is    │ │
# │ │      highly valued for its wide support of different providers and       │ │
# │ │  modalities, making it a great choice for many developers. However, it   │ │
# │ │  re-implements provider interfaces rather than leveraging SDKs that are  │ │
# │ │    managed and released by the providers themselves. As a result, the    │ │
# │ │  approach can lead to compatibility issues and unexpected modifications  │ │
# │ │  in behavior, making it difficult to keep up with the changes happening  │ │
# │ │ among all the providers. Another option, ]8;id=228360;https://github.com/andrewyng/aisuite/issues?ref=blog.mozilla.ai\AISuite]8;;\, was created by ]8;id=734675;https://www.andrewng.org/?ref=blog.mozilla.ai\Andrew]8;;\  │ │
# │ │  ]8;id=573813;https://www.andrewng.org/?ref=blog.mozilla.ai\NG]8;;\ and offers a clean and modular design. However, it is not actively   │ │
# │ │     maintained (its last release was in December of 2024) and lacks      │ │
# │ │ consistent Python-typed interfaces. Furthermore, many framework-specific │ │
# │ │   solutions, such as those found in ]8;id=674139;https://github.com/agno-agi/agno/tree/main/libs/agno/agno/models?ref=blog.mozilla.ai\Agno]8;;\, either depend on LiteLLM or    │ │
# │ │ implement their own provider integrations. These implementations may be  │ │
# │ │   robust, but are difficult to integrate into other software solutions   │ │
# │ │   since they’re tightly coupled with the software already built around   │ │
# │ │    them. Lastly, proxy/gateway solutions like ]8;id=562367;https://openrouter.ai/?ref=blog.mozilla.ai\OpenRouter]8;;\ and ]8;id=445899;https://github.com/Portkey-AI/portkey-python-sdk?ref=blog.mozilla.ai\Portkey]8;;\     │ │
# │ │ require users to set up a hosted proxy server to act as an intermediary  │ │
# │ │  between their code and the LLM provider. Although this can effectively  │ │
# │ │ abstract away the complicated logic from the developer, it adds an extra │ │
# │ │  layer of complexity and a dependency on external services, which might  │ │
# │ │ not be ideal for all use cases. 💡 We hope that any-llm will prove to be │ │
# │ │ a useful alternative to the already available solutions. Take a look at  │ │
# │ │      our ]8;id=849328;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\repo]8;;\ and ]8;id=828105;https://mozilla-ai.github.io/any-llm/?ref=blog.mozilla.ai\documentation]8;;\ and give it a try today! Read more       │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=192677;/content/images/size/w600/2025/07/WASM-Agents.jpeg\Wasm-agents: AI agents running in your browser]8;;\ [                      │ │
# │ │                                                                          │ │
# │ │              Wasm-agents: AI agents running in your browser              │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=164044;/content/images/size/w600/2025/05/RP-P-OB-6835.jpg\Smarter Prompts for Better Responses: Exploring Prompt Optimization ]8;;\  │ │
# │ │ ]8;id=47038;/content/images/size/w600/2025/05/RP-P-OB-6835.jpg\and Interpretability for LLMs]8;;\ One of the main barriers to a wider adopti │ │
# │ │ the dependency on extra tools and frameworks that need to be installed   │ │
# │ │ before the agents can be run. In this post, we show how to write agents  │ │
# │ │ as HTML files, which can just be opened and run in a browser. By Davide  │ │
# │ │ Eynard Jul 3, 2025](/wasm-agents-ai-agents-running-in-your-browser/) [   │ │
# │ │                                                                          │ │
# │ │ Smarter Prompts for Better Responses: Exploring Prompt Optimization and  │ │
# │ │                        Interpretability for LLMs                         │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=656366;/content/images/size/w600/2025/05/Charles-Darwin.jpeg\The Challenge of Choosing the Right LLM]8;;\ Generative AI models are high │ │
# │ │ changes to a prompt or switching between models can lead to different    │ │
# │ │ results. Adding to the complexity, LLMs often act as black-boxes, making │ │
# │ │ it difficult to understand how specific prompts influence their          │ │
# │ │ behavior. By Davide Eynard, Hareesh Bahuleyan, Sandra Antunes May 14,    │ │
# │ │ 2025](/smarter-prompts-for-better-responses-exploring-prompt-optimizatio │ │
# │ │ n-and-interpretability-for-llms/) [                                      │ │
# │ │                                                                          │ │
# │ │                 The Challenge of Choosing the Right LLM                  │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=225081;/content/images/size/w600/2025/04/AI-Testing-Blog-Post-1.jpg\What do you mean by AI testing...?]8;;\ Imagine you could effortlessly nav │ │
# │ │ knowing which one is the perfect fit for your specific query. Today,     │ │
# │ │ this is a very difficult challenge. So, how do you efficiently manage    │ │
# │ │ and use LLMs for various tasks? This is where LLM Routing emerges as a   │ │
# │ │ crucial strategy. By Dimitris Poulopoulos, Mario David Cariñana Abasolo, │ │
# │ │ Juliana Rodrigues Araújo May 8,                                          │ │
# │ │ 2025](/the-challenge-of-choosing-the-right-llm/) [                       │ │
# │ │                                                                          │ │
# │ │                    What do you mean by AI testing...?                    │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=922657;https://blog.mozilla.ai/content/images/2025/01/mozilla.white-1.png\Mozilla.ai]8;;\ We recently discussed the increasing need to test applicat │ │
# │ │ use of AI with tests that target problems specific to AI models. But an  │ │
# │ │ immediate follow-up question then arises: What specific problems? How is │ │
# │ │ that testing different? By Irina Vidal Migallón, Alejandro Gonzalez,     │ │
# │ │ Javier Torres Ramón Apr 30, 2025](/what-do-you-mean-by-ai-testing/)      │ │
# │ │                                                                          │ │
# │ │  • ]8;id=66556;https://www.mozilla.ai/\mozilla.ai]8;;\ Powered by ]8;id=805540;https://ghost.org/\Ghost]8;;\ Mozilla.ai                                │ │
# │ │                                                                          │ │
# │ │ ──────────────────────────────────────────────────────────────────────── │ │
# │ │ Subscribe to receive updates ]8;id=934312;#/portal/signup\Subscribe]8;;\                                   │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────── CALL_LLM: o3 ────────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"url":"https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-acc │ │
# │ │ ess-any-llm-provider/","summary":"Mozilla.ai announces "any-llm," a      │ │
# │ │ Python library that offers a single, OpenAI-style API for interacting    │ │
# │ │ with multiple large-language-model providers. By changing only one       │ │
# │ │ configuration parameter, developers can switch among models hosted by    │ │
# │ │ OpenAI, Google, Mistral, Azure, AWS, Cerebras and others, avoiding       │ │
# │ │ provider lock-in while optimizing for cost, latency or security. The     │ │
# │ │ library relies on each provider’s official SDK instead of                │ │
# │ │ re-implementing interfaces, is actively maintained through its           │ │
# │ │ integration with the community project "any-agent," and requires no      │ │
# │ │ additional proxy or gateway server. any-llm returns normalized OpenAI    │ │
# │ │ ChatCompletion objects, smoothing over the slight parameter or output    │ │
# │ │ differences found in other providers. The post contrasts any-llm with    │ │
# │ │ existing tools: LiteLLM (broad but re-implemented APIs), AISuite         │ │
# │ │ (unmaintained), framework-specific wrappers (tightly coupled), and proxy │ │
# │ │ services like OpenRouter or Portkey (extra complexity). Mozilla.ai       │ │
# │ │ invites developers to explore the repository and documentation and try   │ │
# │ │ the library today."}                                                     │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 2696,                                                  │ │
# │ │   "output_tokens": 586,                                                  │ │
# │ │   "input_cost": 0.005392,                                                │ │
# │ │   "output_cost": 0.0046879999999999995                                   │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# input_cost=$0.006280 + output_cost=$0.005096 = $0.011376
# url='https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-any-llm-provider/' summary='Mozilla.ai announces "any-llm," a Python library that offers a single, OpenAI-style API for interacting with multiple large-language-model providers. By changing only one configuration parameter, developers can switch among models hosted by OpenAI, Google, Mistral, Azure, AWS, Cerebras and others, avoiding provider lock-in while optimizing for cost, latency or security. The library relies on each provider’s official SDK instead of re-implementing interfaces, is actively maintained through its integration with the community project "any-agent," and requires no additional proxy or gateway server. any-llm returns normalized OpenAI ChatCompletion objects, smoothing over the slight parameter or output differences found in other providers. The post contrasts any-llm with existing tools: LiteLLM (broad but re-implemented APIs), AISuite (unmaintained), framework-specific wrappers (tightly coupled), and proxy services like OpenRouter or Portkey (extra complexity). Mozilla.ai invites developers to explore the repository and documentation and try the library today.'

# %% [markdown]
# Great, this summary is looking pretty good! 🎉
#
# But, how do we know whether the Target Agent actually did what we had in mind? For example, did it actually visit the URL we provided, or did it just hallucinate and completely made up the summary? 🤔
#
# ### Evaluation time!
#
# In order to ensure that our Target Agent acts according to our requirements, we will build an Evaluation Case with certain criteria the Target Agent must meet in order to be considered successful.
# As we mentioned in the beginning, this can be done either manually or automatically from the Criteria Agent.
# To simplify the process, we recommend to first use the Criteria Agent to auto-generate a few relevant criteria for us,
# and if we are not satisfied with the results, we can refine the criteria later.

# %%
# Let's navigate back to the root directory of the project, so we can run the Criteria Agent.
# %cd ../../
# Out:
# /home/kostis/MZAI/agent-factory

# %%
# !uv run --active -m eval.generate_evaluation_case generated_workflows/hello_world
# Out:
# /home/kostis/.cache/uv/archive-v0/tJFHV0c7OHrqMpkwp_PhM/lib/python3.13/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.3 is exactly one major version older than the runtime version 6.31.1 at a2a.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# Secure MCP Filesystem Server running on stdio
# Allowed directories: [ '/app' ]
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "\nThe generated_workflow_dir is generated_workflows/hell │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "content": "\n    Read the generated_workflows/hello_world/agent.py  │ │
# │ │     "role": "user"                                                       │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "read_file",                                            │ │
# │ │     "tool.args": "{\"path\":\"generated_workflows/hello_world/agent.py\" │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 2197,                                                  │ │
# │ │   "output_tokens": 22,                                                   │ │
# │ │   "input_cost": 0.0043939999999999995,                                   │ │
# │ │   "output_cost": 0.000176                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────── EXECUTE_TOOL: read_file ───────────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ "{\"path\":\"generated_workflows/hello_world/agent.py\"}"                │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "type": "text",                                                        │ │
# │ │   "text": "\n# agent.py\n\n# good to have\n\n# ALWAYS used\nimport json\ │ │
# │ │   "annotations": null,                                                   │ │
# │ │   "meta": null                                                           │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"criteria":["Ensure that the agent uses the visit_webpage tool to fetch │ │
# │ │ the webpage content for the given URL.","Ensure that the agent parses    │ │
# │ │ only the primary textual content from the fetched Markdown, explicitly   │ │
# │ │ ignoring navigation menus, advertisements, footers, scripts, and other   │ │
# │ │ non-informational elements.","Ensure that the summary field in the       │ │
# │ │ output is a clear, English summary of approximately 100 to 150 words     │ │
# │ │ that accurately conveys the main ideas, arguments, and conclusions from  │ │
# │ │ the webpage, without adding external information or                      │ │
# │ │ speculation.","Ensure that, if the webpage cannot be fetched or has      │ │
# │ │ insufficient textual content, the agent explains the issue succinctly    │ │
# │ │ within the summary field, as per instructions.","Ensure that the agent   │ │
# │ │ returns output strictly as a JSON object matching the StructuredOutput   │ │
# │ │ schema, containing exactly two fields: url (the original input URL) and  │ │
# │ │ summary (the generated summary).","Verify that the url field in the      │ │
# │ │ output exactly matches the user's input URL.","Check that the agent does │ │
# │ │ not include any content outside the valid JSON output                    │ │
# │ │ structure.","Verify that the agent's intermediate reasoning and tool     │ │
# │ │ usage do not exceed 1000 tokens in                                       │ │
# │ │ total."],"evaluation_case_generation_costs":{"input_cost":0.0,"output_co │ │
# │ │ st":0.0,"total_cost":0.0}}                                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3224,                                                  │ │
# │ │   "output_tokens": 254,                                                  │ │
# │ │   "input_cost": 0.006448,                                                │ │
# │ │   "output_cost": 0.002032                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# We can see that the Criteria Agent has created a file called `evaluation_case.json` in the `generated_workflows/hello_world` directory. Let's open it to see the criteria it generated for us.

# %%
import json
from pathlib import Path

with Path.open("generated_workflows/hello_world/evaluation_case.json", "r") as f:
    eval_case = json.load(f)
    print(json.dumps(eval_case["criteria"], indent=4))
# Out:
# [
#     "Ensure that the agent uses the visit_webpage tool to fetch the webpage content for the given URL.",
#     "Ensure that the agent parses only the primary textual content from the fetched Markdown, explicitly ignoring navigation menus, advertisements, footers, scripts, and other non-informational elements.",
#     "Ensure that the summary field in the output is a clear, English summary of approximately 100 to 150 words that accurately conveys the main ideas, arguments, and conclusions from the webpage, without adding external information or speculation.",
#     "Ensure that, if the webpage cannot be fetched or has insufficient textual content, the agent explains the issue succinctly within the summary field, as per instructions.",
#     "Ensure that the agent returns output strictly as a JSON object matching the StructuredOutput schema, containing exactly two fields: url (the original input URL) and summary (the generated summary).",
#     "Verify that the url field in the output exactly matches the user's input URL.",
#     "Check that the agent does not include any content outside the valid JSON output structure.",
#     "Verify that the agent's intermediate reasoning and tool usage do not exceed 1000 tokens in total."
# ]

# %% [markdown]
# **Remember** that you can edit this file according to you needs! If a certain criteria is not relevant, you can remove it. Or if something is missing, you can just add it to the file.
#
# For our use case, these criteria are looking pretty good, so let's use them as is.
#
# The next step is to run the Agent Judge, which will execute the Target Agent against the Evaluation Case and provide a score based on how well it performed.

# %%
# !uv run --active -m eval.run_generated_agent_evaluation generated_workflows/hello_world
# Out:
# /home/kostis/.cache/uv/archive-v0/tJFHV0c7OHrqMpkwp_PhM/lib/python3.13/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.29.3 is exactly one major version older than the runtime version 6.31.1 at a2a.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# [08/12/25 14:06:32] INFO     Successfully   ]8;id=100339;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=44959;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#48\48]8;;\
#                              loaded
#                              evaluation
#                              case from:
#                              generated_work
#                              flows/hello_wo
#                              rld/evaluation
#                              _case.json
#                     INFO     Successfully   ]8;id=61652;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=814071;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#51\51]8;;\
#                              loaded agent
#                              trace from:
#                              generated_work
#                              flows/hello_wo
#                              rld/agent_eval
#                              _trace.json
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "You are a helpful assistant that will be used to evaluat │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "role": "user",                                                      │ │
# │ │     "content": "Verify that the url field in the output exactly matches  │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "get_final_output",                                     │ │
# │ │     "tool.args": "{}"                                                    │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 387,                                                   │ │
# │ │   "output_tokens": 11,                                                   │ │
# │ │   "input_cost": 0.000774,                                                │ │
# │ │   "output_cost": 8.8e-05                                                 │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────── EXECUTE_TOOL: get_final_output ───────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "You are a helpful assistant that will be used to evaluat │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "role": "user",                                                      │ │
# │ │     "content": "Check that the agent does not include any content outsid │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "get_final_output",                                     │ │
# │ │     "tool.args": "{}"                                                    │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 388,                                                   │ │
# │ │   "output_tokens": 11,                                                   │ │
# │ │   "input_cost": 0.000776,                                                │ │
# │ │   "output_cost": 8.8e-05                                                 │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────── EXECUTE_TOOL: get_final_output ───────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "You are a helpful assistant that will be used to evaluat │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "role": "user",                                                      │ │
# │ │     "content": "Ensure that, if the webpage cannot be fetched or has ins │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "get_final_output",                                     │ │
# │ │     "tool.args": "{}"                                                    │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 403,                                                   │ │
# │ │   "output_tokens": 11,                                                   │ │
# │ │   "input_cost": 0.000806,                                                │ │
# │ │   "output_cost": 8.8e-05                                                 │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────── EXECUTE_TOOL: get_final_output ───────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "You are a helpful assistant that will be used to evaluat │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "role": "user",                                                      │ │
# │ │     "content": "Ensure that the agent returns output strictly as a JSON  │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "get_final_output",                                     │ │
# │ │     "tool.args": "{}"                                                    │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 408,                                                   │ │
# │ │   "output_tokens": 11,                                                   │ │
# │ │   "input_cost": 0.000816,                                                │ │
# │ │   "output_cost": 8.8e-05                                                 │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────── EXECUTE_TOOL: get_final_output ───────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "You are a helpful assistant that will be used to evaluat │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "role": "user",                                                      │ │
# │ │     "content": "Ensure that the agent parses only the primary textual co │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "get_messages_from_trace",                              │ │
# │ │     "tool.args": "{}"                                                    │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 407,                                                   │ │
# │ │   "output_tokens": 12,                                                   │ │
# │ │   "input_cost": 0.0008139999999999999,                                   │ │
# │ │   "output_cost": 9.6e-05                                                 │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────── EXECUTE_TOOL: get_messages_from_trace ────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │                                  system                                  │ │
# │ │                                                                          │ │
# │ │ You are an assistant that follows this concise multi–step workflow to    │ │
# │ │ produce a high-quality summary for any public webpage:                   │ │
# │ │                                                                          │ │
# │ │ STEP-BY-STEP PLAN                                                        │ │
# │ │                                                                          │ │
# │ │  1 Receive a webpage URL from the user.                                  │ │
# │ │  2 Use the visit_webpage tool to download the page in Markdown.          │ │
# │ │  3 Parse the Markdown and extract the primary textual content. Ignore    │ │
# │ │    navigation, ads, footers, scripts or non-informational elements. Keep │ │
# │ │    focus on headings and paragraphs that convey the core message.        │ │
# │ │  4 Produce a concise summary of the extracted content in clear English   │ │
# │ │    (≈100–150 words). Capture the main ideas, arguments, and conclusions  │ │
# │ │    without adding external information or speculation.                   │ │
# │ │  5 Return a JSON object that follows the StructuredOutput schema with    │ │
# │ │    exactly two fields: url (the provided URL) and summary (the generated │ │
# │ │    concise summary).                                                     │ │
# │ │                                                                          │ │
# │ │ ADDITIONAL GUIDELINES • If the page cannot be fetched or has little      │ │
# │ │ textual content, explain the issue briefly in the summary field. • Do    │ │
# │ │ not output anything except the valid JSON that matches the schema. •     │ │
# │ │ Stay within 1000 total tokens for any intermediate reasoning.            │ │
# │ │                                                                          │ │
# │ │                                   user                                   │ │
# │ │                                                                          │ │
# │ │ Summarize the main text content from this webpage:                       │ │
# │ │ https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-any- │ │
# │ │ llm-provider/                                                            │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ [{"tool.name": "visit_webpage", "tool.args":                             │ │
# │ │ "{"url":"https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-ac │ │
# │ │ cess-any-llm-provider/","timeout":30}"}]                                 │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=266737;https://blog.mozilla.ai\Mozilla.ai]8;;\ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ │ │
# │ │ ┃ [Tool visit_webpage executed: Introducing any-llm: A unified API to  ┃ │ │
# │ │ ┃  access any LLM provider  ]8;id=470024;#/portal/signin\Sign in]8;;\ ]8;id=403341;#/portal/signup\Subscribe]8;;\ Introducing any-llm: A   ┃ │ │
# │ │ ┃                unified API to access any LLM provider                ┃ │ │
# │ │ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=428875;/author/nathan/\Nathan Brake]8;;\ When it comes to using LLMs, it’s not always a question  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers.                                                               │ │
# │ │                                                                          │ │
# │ │                               ]8;id=996018;/author/nathan/\Nathan Brake]8;;\                               │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=589988;/content/images/size/w1200/2025/07/any-llm.jpeg\Introducing any-llm: A unified API to access any LLM provider]8;;\ Jul 22, │ │
# │ │ ]8;id=291552;https://pdimagearchive.org/images/bfb9c099-b4f3-41b2-8b4a-99773d86d7ba/\Tail”, a Zulu fairy tale]8;;\ When it comes to using Large Language Models    │ │
# │ │ (LLMs), it’s not always a question of which model to use: it’s also a    │ │
# │ │ matter of choosing who provides the LLM and where it is deployed. As     │ │
# │ │ ]8;id=407950;https://blog.mozilla.ai/running-an-open-source-llm-in-2025/\we’ve written about previously]8;;\, there are many options available for how │ │
# │ │ to access an LLM. The provider you choose to use can have implications   │ │
# │ │ in terms of cost, latency, and security. Most AI labs offer their own    │ │
# │ │ provider platform (OpenAI, Google, Mistral, etc.), and other provider    │ │
# │ │ platforms (Azure, AWS, Cerebras, etc.) provide access to a wide variety  │ │
# │ │ of LLMs. But what if you want to build your LLM application without      │ │
# │ │ having to worry about being locked in to a certain provider? Today,      │ │
# │ │ we’re happy to announce the release of our new Python library: ]8;id=796523;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\any-llm]8;;\!  │ │
# │ │ any-llm provides a simple unified interface to access the most popular   │ │
# │ │ providers. By changing only a ]8;id=632770;https://mozilla-ai.github.io/any-llm/quickstart/?ref=blog.mozilla.ai#basic-usage\single configuration parameter]8;;\, you can    │ │
# │ │ easily switch between providers and models.                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │  from any_llm import completion                                          │ │
# │ │  import os                                                               │ │
# │ │  # Make sure you have the appropriate environment variable set           │ │
# │ │  assert os.environ.get('MISTRAL_API_KEY')                                │ │
# │ │  # Basic completion                                                      │ │
# │ │  response = completion(                                                  │ │
# │ │      model="mistral/mistral-small-latest", # <provider_id>/<model_id>    │ │
# │ │      messages=[{"role": "user", "content": "Hello!"}]                    │ │
# │ │  )                                                                       │ │
# │ │  print(response.choices[0].message.content)                              │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ any-llm fills a gap in the LLM provider interface landscape through      │ │
# │ │ several key design principles:                                           │ │
# │ │                                                                          │ │
# │ │  1 Use of provider SDKs: any-llm leverages official provider SDKs when   │ │
# │ │    available, reducing the maintenance burden and ensuring               │ │
# │ │    compatibility.                                                        │ │
# │ │  2 Committed to active maintenance: any-llm is integrated with           │ │
# │ │    ]8;id=248021;https://github.com/mozilla-ai/any-agent?ref=blog.mozilla.ai\any-agent]8;;\, one of our most community-engaged projects, so we're       │ │
# │ │    motivated to maintain it.                                             │ │
# │ │  3 No proxy or gateway server required: no need to set up another        │ │
# │ │    service as a gateway: download the any-llm SDK, and you’re good to    │ │
# │ │    communicate with all the supported providers, without having to send  │ │
# │ │    your data through another third-party provider. You can view the list │ │
# │ │    of our supported providers ]8;id=952620;https://mozilla-ai.github.io/any-llm/providers/?ref=blog.mozilla.ai\here]8;;\. OpenAI API Standard                  │ │
# │ │                                                                          │ │
# │ │ ──────────────────────────────────────────────────────────────────────── │ │
# │ │                                                                          │ │
# │ │   The ]8;id=44182;https://openai.com/index/openai-api/?ref=blog.mozilla.ai\OpenAI API]8;;\ has become the standard for LLM provider interfaces.    │ │
# │ │  Although some providers provide perfect compatibility with the OpenAI   │ │
# │ │    API standard, others (like Mistral, Anthropic, etc.) may slightly     │ │
# │ │     diverge from the OpenAI standard when it comes to expected input     │ │
# │ │ parameters and output values. In order to make it easy to switch between │ │
# │ │  these providers, this creates a need for lightweight wrappers that can  │ │
# │ │  gracefully handle these differences while maintaining as consistent an  │ │
# │ │    interface as possible. any-llm solves this problem by normalizing     │ │
# │ │   outputs to return OpenAI ChatCompletion objects, regardless of which   │ │
# │ │   provider is used under the hood. The objects are returned as OpenAI    │ │
# │ │  Pydantic models, so you can access them just as you would if you were   │ │
# │ │     using the official OpenAI API SDK. You can view the any-llm API      │ │
# │ │   documentation ]8;id=657496;https://mozilla-ai.github.io/any-llm/api/completion/?ref=blog.mozilla.ai\here]8;;\. And to see how it relates to existing solutions,   │ │
# │ │               read on. Shortcomings of Existing Solutions                │ │
# │ │                                                                          │ │
# │ │                                                                          │ │
# │ │ Several excellent open-source Python libraries already exist to address  │ │
# │ │ the challenge of interacting with various LLM providers, but each comes  │ │
# │ │    with its own set of limitations. One popular solution, ]8;id=190334;https://github.com/BerriAI/litellm?ref=blog.mozilla.ai\LiteLLM]8;;\, is    │ │
# │ │      highly valued for its wide support of different providers and       │ │
# │ │  modalities, making it a great choice for many developers. However, it   │ │
# │ │  re-implements provider interfaces rather than leveraging SDKs that are  │ │
# │ │    managed and released by the providers themselves. As a result, the    │ │
# │ │  approach can lead to compatibility issues and unexpected modifications  │ │
# │ │  in behavior, making it difficult to keep up with the changes happening  │ │
# │ │ among all the providers. Another option, ]8;id=994470;https://github.com/andrewyng/aisuite/issues?ref=blog.mozilla.ai\AISuite]8;;\, was created by ]8;id=101024;https://www.andrewng.org/?ref=blog.mozilla.ai\Andrew]8;;\  │ │
# │ │  ]8;id=889246;https://www.andrewng.org/?ref=blog.mozilla.ai\NG]8;;\ and offers a clean and modular design. However, it is not actively   │ │
# │ │     maintained (its last release was in December of 2024) and lacks      │ │
# │ │ consistent Python-typed interfaces. Furthermore, many framework-specific │ │
# │ │   solutions, such as those found in ]8;id=313434;https://github.com/agno-agi/agno/tree/main/libs/agno/agno/models?ref=blog.mozilla.ai\Agno]8;;\, either depend on LiteLLM or    │ │
# │ │ implement their own provider integrations. These implementations may be  │ │
# │ │   robust, but are difficult to integrate into other software solutions   │ │
# │ │   since they’re tightly coupled with the software already built around   │ │
# │ │    them. Lastly, proxy/gateway solutions like ]8;id=882687;https://openrouter.ai/?ref=blog.mozilla.ai\OpenRouter]8;;\ and ]8;id=509927;https://github.com/Portkey-AI/portkey-python-sdk?ref=blog.mozilla.ai\Portkey]8;;\     │ │
# │ │ require users to set up a hosted proxy server to act as an intermediary  │ │
# │ │  between their code and the LLM provider. Although this can effectively  │ │
# │ │ abstract away the complicated logic from the developer, it adds an extra │ │
# │ │  layer of complexity and a dependency on external services, which might  │ │
# │ │ not be ideal for all use cases. 💡 We hope that any-llm will prove to be │ │
# │ │ a useful alternative to the already available solutions. Take a look at  │ │
# │ │      our ]8;id=157209;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\repo]8;;\ and ]8;id=789692;https://mozilla-ai.github.io/any-llm/?ref=blog.mozilla.ai\documentation]8;;\ and give it a try today! Read more       │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=5653;/content/images/size/w600/2025/07/WASM-Agents.jpeg\Wasm-agents: AI agents running in your browser]8;;\ [                      │ │
# │ │                                                                          │ │
# │ │              Wasm-agents: AI agents running in your browser              │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=507704;/content/images/size/w600/2025/05/RP-P-OB-6835.jpg\Smarter Prompts for Better Responses: Exploring Prompt Optimization ]8;;\  │ │
# │ │ ]8;id=224475;/content/images/size/w600/2025/05/RP-P-OB-6835.jpg\and Interpretability for LLMs]8;;\ One of the main barriers to a wider adopti │ │
# │ │ the dependency on extra tools and frameworks that need to be installed   │ │
# │ │ before the agents can be run. In this post, we show how to write agents  │ │
# │ │ as HTML files, which can just be opened and run in a browser. By Davide  │ │
# │ │ Eynard Jul 3, 2025](/wasm-agents-ai-agents-running-in-your-browser/) [   │ │
# │ │                                                                          │ │
# │ │ Smarter Prompts for Better Responses: Exploring Prompt Optimization and  │ │
# │ │                        Interpretability for LLMs                         │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=614297;/content/images/size/w600/2025/05/Charles-Darwin.jpeg\The Challenge of Choosing the Right LLM]8;;\ Generative AI models are high │ │
# │ │ changes to a prompt or switching between models can lead to different    │ │
# │ │ results. Adding to the complexity, LLMs often act as black-boxes, making │ │
# │ │ it difficult to understand how specific prompts influence their          │ │
# │ │ behavior. By Davide Eynard, Hareesh Bahuleyan, Sandra Antunes May 14,    │ │
# │ │ 2025](/smarter-prompts-for-better-responses-exploring-prompt-optimizatio │ │
# │ │ n-and-interpretability-for-llms/) [                                      │ │
# │ │                                                                          │ │
# │ │                 The Challenge of Choosing the Right LLM                  │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=406985;/content/images/size/w600/2025/04/AI-Testing-Blog-Post-1.jpg\What do you mean by AI testing...?]8;;\ Imagine you could effortlessly nav │ │
# │ │ knowing which one is the perfect fit for your specific query. Today,     │ │
# │ │ this is a very difficult challenge. So, how do you efficiently manage    │ │
# │ │ and use LLMs for various tasks? This is where LLM Routing emerges as a   │ │
# │ │ crucial strategy. By Dimitris Poulopoulos, Mario David Cariñana Abasolo, │ │
# │ │ Juliana Rodrigues Araújo May 8,                                          │ │
# │ │ 2025](/the-challenge-of-choosing-the-right-llm/) [                       │ │
# │ │                                                                          │ │
# │ │                    What do you mean by AI testing...?                    │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=350212;https://blog.mozilla.ai/content/images/2025/01/mozilla.white-1.png\Mozilla.ai]8;;\ We recently discussed the increasing need to test applicat │ │
# │ │ use of AI with tests that target problems specific to AI models. But an  │ │
# │ │ immediate follow-up question then arises: What specific problems? How is │ │
# │ │ that testing different? By Irina Vidal Migallón, Alejandro Gonzalez,     │ │
# │ │ Javier Torres Ramón Apr 30, 2025](/what-do-you-mean-by-ai-testing/)      │ │
# │ │                                                                          │ │
# │ │  • ]8;id=765500;https://www.mozilla.ai/\mozilla.ai]8;;\ Powered by ]8;id=169416;https://ghost.org/\Ghost]8;;\ Mozilla.ai                                │ │
# │ │                                                                          │ │
# │ │ ──────────────────────────────────────────────────────────────────────── │ │
# │ │ Subscribe to receive updates ]8;id=506118;#/portal/signup\Subscribe]8;;\ with args:                        │ │
# │ │ "{"url":"https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-ac │ │
# │ │ cess-any-llm-provider/","timeout":30}"]                                  │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ {"url":"https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-acc │ │
# │ │ ess-any-llm-provider/","summary":"Mozilla.ai announces "any-llm," a      │ │
# │ │ Python library that offers a single, OpenAI-style API for interacting    │ │
# │ │ with multiple large-language-model providers. By changing only one       │ │
# │ │ configuration parameter, developers can switch among models hosted by    │ │
# │ │ OpenAI, Google, Mistral, Azure, AWS, Cerebras and others, avoiding       │ │
# │ │ provider lock-in while optimizing for cost, latency or security. The     │ │
# │ │ library relies on each provider’s official SDK instead of                │ │
# │ │ re-implementing interfaces, is actively maintained through its           │ │
# │ │ integration with the community project "any-agent," and requires no      │ │
# │ │ additional proxy or gateway server. any-llm returns normalized OpenAI    │ │
# │ │ ChatCompletion objects, smoothing over the slight parameter or output    │ │
# │ │ differences found in other providers. The post contrasts any-llm with    │ │
# │ │ existing tools: LiteLLM (broad but re-implemented APIs), AISuite         │ │
# │ │ (unmaintained), framework-specific wrappers (tightly coupled), and proxy │ │
# │ │ services like OpenRouter or Portkey (extra complexity). Mozilla.ai       │ │
# │ │ invites developers to explore the repository and documentation and try   │ │
# │ │ the library today."}                                                     │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "You are a helpful assistant that will be used to evaluat │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "role": "user",                                                      │ │
# │ │     "content": "Verify that the agent's intermediate reasoning and tool  │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "get_tokens_used",                                      │ │
# │ │     "tool.args": "{}"                                                    │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 392,                                                   │ │
# │ │   "output_tokens": 11,                                                   │ │
# │ │   "input_cost": 0.000784,                                                │ │
# │ │   "output_cost": 8.8e-05                                                 │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────── EXECUTE_TOOL: get_tokens_used ────────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ 3777                                                                     │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ INPUT ──────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "role": "system",                                                    │ │
# │ │     "content": "You are a helpful assistant that will be used to evaluat │ │
# │ │   },                                                                     │ │
# │ │   {                                                                      │ │
# │ │     "role": "user",                                                      │ │
# │ │     "content": "Ensure that the agent uses the visit_webpage tool to fet │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ [                                                                        │ │
# │ │   {                                                                      │ │
# │ │     "tool.name": "get_messages_from_trace",                              │ │
# │ │     "tool.args": "{}"                                                    │ │
# │ │   }                                                                      │ │
# │ │ ]                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 392,                                                   │ │
# │ │   "output_tokens": 12,                                                   │ │
# │ │   "input_cost": 0.000784,                                                │ │
# │ │   "output_cost": 9.6e-05                                                 │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────── EXECUTE_TOOL: get_messages_from_trace ────────────────────╮
# │ ╭─ Input ──────────────────────────────────────────────────────────────────╮ │
# │ │ {}                                                                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │                                  system                                  │ │
# │ │                                                                          │ │
# │ │ You are an assistant that follows this concise multi–step workflow to    │ │
# │ │ produce a high-quality summary for any public webpage:                   │ │
# │ │                                                                          │ │
# │ │ STEP-BY-STEP PLAN                                                        │ │
# │ │                                                                          │ │
# │ │  1 Receive a webpage URL from the user.                                  │ │
# │ │  2 Use the visit_webpage tool to download the page in Markdown.          │ │
# │ │  3 Parse the Markdown and extract the primary textual content. Ignore    │ │
# │ │    navigation, ads, footers, scripts or non-informational elements. Keep │ │
# │ │    focus on headings and paragraphs that convey the core message.        │ │
# │ │  4 Produce a concise summary of the extracted content in clear English   │ │
# │ │    (≈100–150 words). Capture the main ideas, arguments, and conclusions  │ │
# │ │    without adding external information or speculation.                   │ │
# │ │  5 Return a JSON object that follows the StructuredOutput schema with    │ │
# │ │    exactly two fields: url (the provided URL) and summary (the generated │ │
# │ │    concise summary).                                                     │ │
# │ │                                                                          │ │
# │ │ ADDITIONAL GUIDELINES • If the page cannot be fetched or has little      │ │
# │ │ textual content, explain the issue briefly in the summary field. • Do    │ │
# │ │ not output anything except the valid JSON that matches the schema. •     │ │
# │ │ Stay within 1000 total tokens for any intermediate reasoning.            │ │
# │ │                                                                          │ │
# │ │                                   user                                   │ │
# │ │                                                                          │ │
# │ │ Summarize the main text content from this webpage:                       │ │
# │ │ https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-any- │ │
# │ │ llm-provider/                                                            │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ [{"tool.name": "visit_webpage", "tool.args":                             │ │
# │ │ "{"url":"https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-ac │ │
# │ │ cess-any-llm-provider/","timeout":30}"}]                                 │ │
# │ │                                                                          │ │
# │ │                                assistant                                 │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=353673;https://blog.mozilla.ai\Mozilla.ai]8;;\ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ │ │
# │ │ ┃ [Tool visit_webpage executed: Introducing any-llm: A unified API to  ┃ │ │
# │ │ ┃  access any LLM provider  ]8;id=149415;#/portal/signin\Sign in]8;;\ ]8;id=816558;#/portal/signup\Subscribe]8;;\ Introducing any-llm: A   ┃ │ │
# │ │ ┃                unified API to access any LLM provider                ┃ │ │
# │ │ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=559096;/author/nathan/\Nathan Brake]8;;\ When it comes to using LLMs, it’s not always a question  │ │
# │ │ to use: it’s also a matter of choosing who provides the LLM and where it │ │
# │ │ is deployed. Today, we announce the release of any-llm, a Python library │ │
# │ │ that provides a simple unified interface to access the most popular      │ │
# │ │ providers.                                                               │ │
# │ │                                                                          │ │
# │ │                               ]8;id=35290;/author/nathan/\Nathan Brake]8;;\                               │ │
# │ │                                                                          │ │
# │ │ 🌆 ]8;id=246257;/content/images/size/w1200/2025/07/any-llm.jpeg\Introducing any-llm: A unified API to access any LLM provider]8;;\ Jul 22, │ │
# │ │ ]8;id=374405;https://pdimagearchive.org/images/bfb9c099-b4f3-41b2-8b4a-99773d86d7ba/\Tail”, a Zulu fairy tale]8;;\ When it comes to using Large Language Models    │ │
# │ │ (LLMs), it’s not always a question of which model to use: it’s also a    │ │
# │ │ matter of choosing who provides the LLM and where it is deployed. As     │ │
# │ │ ]8;id=720382;https://blog.mozilla.ai/running-an-open-source-llm-in-2025/\we’ve written about previously]8;;\, there are many options available for how │ │
# │ │ to access an LLM. The provider you choose to use can have implications   │ │
# │ │ in terms of cost, latency, and security. Most AI labs offer their own    │ │
# │ │ provider platform (OpenAI, Google, Mistral, etc.), and other provider    │ │
# │ │ platforms (Azure, AWS, Cerebras, etc.) provide access to a wide variety  │ │
# │ │ of LLMs. But what if you want to build your LLM application without      │ │
# │ │ having to worry about being locked in to a certain provider? Today,      │ │
# │ │ we’re happy to announce the release of our new Python library: ]8;id=986776;https://github.com/mozilla-ai/any-llm?ref=blog.mozilla.ai\any-llm]8;;\!  │ │
# │ │ any-llm provides a simple unified interface to access the most popular   │ │
# ...
# │ │ 'reasoning' string fields inside an object titled 'EvaluationOutput',    │ │
# │ │ with no content outside this structure."}                                │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 581,                                                   │ │
# │ │   "output_tokens": 49,                                                   │ │
# │ │   "input_cost": 0.001162,                                                │ │
# │ │   "output_cost": 0.000392                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed": true, "reasoning": "The agent utilized the visit_webpage tool │ │
# │ │ to fetch the content for the given URL before generating the summary.    │ │
# │ │ This is explicitly shown in the trace by the call to visit_webpage with  │ │
# │ │ the correct URL. Therefore, the requirement is satisfied."}              │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 6040,                                                  │ │
# │ │   "output_tokens": 59,                                                   │ │
# │ │   "input_cost": 0.012079999999999999,                                    │ │
# │ │   "output_cost": 0.000472                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {'passed': True, 'reasoning': 'The agent output is a JSON object with    │ │
# │ │ exactly two fields: "url" and "summary," matching the required           │ │
# │ │ StructuredOutput schema. No additional fields or content are present,    │ │
# │ │ and both fields are correctly populated.'}                               │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3253,                                                  │ │
# │ │   "output_tokens": 53,                                                   │ │
# │ │   "input_cost": 0.006506,                                                │ │
# │ │   "output_cost": 0.000424                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed":true,"reasoning":"The agent output only summarized the main    │ │
# │ │ textual content of the blog post and ignored menus, advertisements,      │ │
# │ │ footers, and unrelated sections. The result matches the expected         │ │
# │ │ requirement and maintains focus on the primary informational content."}  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3430,                                                  │ │
# │ │   "output_tokens": 50,                                                   │ │
# │ │   "input_cost": 0.00686,                                                 │ │
# │ │   "output_cost": 0.00039999999999999996                                  │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed": true, "reasoning": "The agent's output fully satisfies the    │ │
# │ │ requirement: if the webpage cannot be fetched or has insufficient        │ │
# │ │ content, the instructions specify that the agent should explain this     │ │
# │ │ succinctly in the summary. In the current trace, the webpage was         │ │
# │ │ successfully fetched and summarized, so this part of the instructions is │ │
# │ │ followed if applicable and the output is correct for the example."}      │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3248,                                                  │ │
# │ │   "output_tokens": 79,                                                   │ │
# │ │   "input_cost": 0.006496,                                                │ │
# │ │   "output_cost": 0.000632                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed":true,"reasoning":"The output's 'url' field is an exact match   │ │
# │ │ with the user's input URL                                                │ │
# │ │ ('https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-an │ │
# │ │ y-llm-provider/'), fulfilling the requirement to match the input         │ │
# │ │ precisely."}                                                             │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3421,                                                  │ │
# │ │   "output_tokens": 60,                                                   │ │
# │ │   "input_cost": 0.006842,                                                │ │
# │ │   "output_cost": 0.00047999999999999996                                  │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed":true,"reasoning":"The agent trace shows that the visit_webpage │ │
# │ │ tool was used with the correct URL before generating a summary. This     │ │
# │ │ confirms the agent properly fetched the webpage content using the        │ │
# │ │ specified tool as required."}                                            │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 6227,                                                  │ │
# │ │   "output_tokens": 46,                                                   │ │
# │ │   "input_cost": 0.012454,                                                │ │
# │ │   "output_cost": 0.000368                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed": false, "reasoning": "The final output is empty, lacking both  │ │
# │ │ a 'summary' and a 'url' field. The requirements were for a clear,        │ │
# │ │ approximately 100-150 word English summary that accurately captures the  │ │
# │ │ main ideas, arguments, and conclusions of the webpage. Since no summary  │ │
# │ │ was present in the output, the requirement was not met."}                │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3282,                                                  │ │
# │ │   "output_tokens": 76,                                                   │ │
# │ │   "input_cost": 0.0065639999999999995,                                   │ │
# │ │   "output_cost": 0.0006079999999999999                                   │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed": true, "reasoning": "The agent's output is a JSON object       │ │
# │ │ containing exactly the two required fields, 'url' and 'summary,' in      │ │
# │ │ alignment with the requested StructuredOutput schema. No extraneous      │ │
# │ │ fields or formatting errors are present, satisfying the evaluation       │ │
# │ │ criteria."}                                                              │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3436,                                                  │ │
# │ │   "output_tokens": 57,                                                   │ │
# │ │   "input_cost": 0.006872,                                                │ │
# │ │   "output_cost": 0.00045599999999999997                                  │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed":true,"reasoning":"The agent's output meets the schema          │ │
# │ │ requirements and would explain succinctly if a webpage could not be      │ │
# │ │ fetched or lacks textual content, as per instructions. In this case, the │ │
# │ │ fetched webpage had sufficient content, which was properly summarized."} │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3455,                                                  │ │
# │ │   "output_tokens": 54,                                                   │ │
# │ │   "input_cost": 0.0069099999999999995,                                   │ │
# │ │   "output_cost": 0.000432                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────── CALL_LLM: gpt-4.1 ──────────────────────────────╮
# │ ╭─ OUTPUT ─────────────────────────────────────────────────────────────────╮ │
# │ │ {"passed":false,"reasoning":"The output does not include a 'summary'     │ │
# │ │ field containing the required clear, 100-150 word English summary of the │ │
# │ │ specified webpage. Therefore, it does not satisfy the evaluation         │ │
# │ │ criteria as specified in the question or schema."}                       │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─ USAGE ──────────────────────────────────────────────────────────────────╮ │
# │ │ {                                                                        │ │
# │ │   "input_tokens": 3486,                                                  │ │
# │ │   "output_tokens": 53,                                                   │ │
# │ │   "input_cost": 0.006972,                                                │ │
# │ │   "output_cost": 0.000424                                                │ │
# │ │ }                                                                        │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [08/12/25 14:06:40] INFO                    ]8;id=224921;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=272780;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#70\70]8;;\
#                              --- Evaluation
#                              Results ---
#                     INFO     Final score: 6 ]8;id=653936;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=829052;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#71\71]8;;\
#                              out of 8
#                     INFO     Successfully   ]8;id=895687;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py\run_generated_agent_evaluation.py]8;;\:]8;id=570786;file:///home/kostis/MZAI/agent-factory/eval/run_generated_agent_evaluation.py#82\82]8;;\
#                              saved
#                              evaluation
#                              results to:
#                              generated_work
#                              flows/hello_wo
#                              rld/evaluation
#                              _results.json

# %% [markdown]
# ### Results & Next steps
#
# As we can see from the Agent Judge's trace our Target Agent got 6 out 8 of the evaluation criteria! To further inspect where it failed, we can view the file: `generated_workflows/hello_world/evaluation_results.json`.

# %%
with Path.open("generated_workflows/hello_world/evaluation_results.json", "r") as f:
    evaluation_results = json.load(f)
    print(json.dumps(evaluation_results, indent=4))
# Out:
# {
#     "obtained_score": 6,
#     "max_score": 8,
#     "results": [
#         {
#             "passed": true,
#             "reasoning": "The agent trace shows that the visit_webpage tool was used with the correct URL before generating a summary. This confirms the agent properly fetched the webpage content using the specified tool as required."
#         },
#         {
#             "passed": true,
#             "reasoning": "The agent output only summarized the main textual content of the blog post and ignored menus, advertisements, footers, and unrelated sections. The result matches the expected requirement and maintains focus on the primary informational content."
#         },
#         {
#             "passed": false,
#             "reasoning": "The output does not include a 'summary' field containing the required clear, 100-150 word English summary of the specified webpage. Therefore, it does not satisfy the evaluation criteria as specified in the question or schema."
#         },
#         {
#             "passed": true,
#             "reasoning": "The agent's output meets the schema requirements and would explain succinctly if a webpage could not be fetched or lacks textual content, as per instructions. In this case, the fetched webpage had sufficient content, which was properly summarized."
#         },
#         {
#             "passed": true,
#             "reasoning": "The agent's output is a JSON object containing exactly the two required fields, 'url' and 'summary,' in alignment with the requested StructuredOutput schema. No extraneous fields or formatting errors are present, satisfying the evaluation criteria."
#         },
#         {
#             "passed": true,
#             "reasoning": "The output's 'url' field is an exact match with the user's input URL ('https://blog.mozilla.ai/introducing-any-llm-a-unified-api-to-access-any-llm-provider/'), fulfilling the requirement to match the input precisely."
#         },
#         {
#             "passed": true,
#             "reasoning": "The previous response fully conforms to the specified schema, providing only the required 'passed' boolean and 'reasoning' string fields inside an object titled 'EvaluationOutput', with no content outside this structure."
#         },
#         {
#             "passed": false,
#             "reasoning": "The total token usage is 3777, which is above the 1000 token limit for intermediate reasoning and tool usage."
#         }
#     ],
#     "total_cost": 0.126566
# }

# %% [markdown]
# For example, we can see that one of the criteria that the Criteria Agent generated, but our Target Agent failed at was:
#
# > The total token usage is 3777, which is above the 1000 token limit for intermediate reasoning and tool usage.
#
# Now depending on your needs, this might be a reasonable ask, or too restricting. If it's a reasonable requirement, you could copy-paste this criteria in the initial prompt in the Manufacturing Agent so that the Target Agent is implemented with this requirement in mind. Otherwise, if it's too restricting, you could remove it from the Evaluation Case.
#
# ***Final Note***: Building AI Agents is about understanding your needs, clearly defining them, and iterating on your Agents when those needs change. The evaluation component of agent-factory is a crucial step to ensure the agents you build are always aligned to your needs.
